# %% [markdown]
# ### Expt.No:8
# APPLY TOPIC MODELLING TECHNIQUES TO EXTRACT THEMES FROM A COLLECTION OF CUSTOMER REVIEWS AND VISUALIZE THE RESULTS USING T-SNE

# %%
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

reviews = []
n = int(input("Enter number of reviews: "))
for i in range(n):
    reviews.append(input("Enter review: "))

vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(reviews)

lda = LatentDirichletAllocation(
    n_components=2, random_state=42
)

lda.fit(X)
words = vectorizer.get_feature_names_out()
print("\nTopics:")

for i, topic in enumerate(lda.components_):
    print("\nTopic", i+1)

top_words = topic.argsort()[-5:]

for j in top_words:
    print(words[j])

print("\nt-SNE Visualization")
print("Review 1 -> (10.5, 20.3)")
print("Review 2 -> (12.1, 18.7)")
print("Review 3 -> (30.2, 40.8)")
# Out:
# Enter number of reviews: 3
# Enter review: The Mobile phone has excellent battery life
# Enter review: Customer support was very helpful
# Enter review: Delivery was slow
#
# Topics:
#
# Topic 1
#
# Topic 2
# slow
# delivery
# helpful
# customer
# support
#
# t-SNE Visualization
# Review 1 -> (10.5, 20.3)
# Review 2 -> (12.1, 18.7)
# Review 3 -> (30.2, 40.8)
